# %%
import pandas as pd
import numpy as np
import os
import json
import matplotlib.pyplot as plt
# %matplotlib inline
os.getcwd()
os.chdir('/Users/kylehoward/desktop/thinkful') 
os.getcwd()
# Out:
# '/Users/kylehoward/Desktop/Thinkful'

# %%
# Building dataframe of fantasy points scored against each team broken down by position and 
# an average of similar positions
fp = pd.DataFrame(pd.read_csv('FPPG.csv', nrows=30))
fp.columns = ['pg', 'sg', 'sf', 'pf', 'c']
fp.index = ['atl', 'bos', 'bkn', 'cha', 'chi', 'cle', 'dal', 'den', 'det', 'gsw', 'hou', 'ind', 'lac', 'lal', 'mem', 'mia', 'mil', 'min', 'nop', 'nyk', 'okc', 'orl', 'phi', 'pho', 'por', 'sac', 'sas', 'tor', 'uth', 'was']
fp['pg_sg'] = (fp['pg'] + fp['sg']) / 2
fp['sg_sf'] = (fp['sg'] + fp['sf']) / 2
fp['sf_pf'] = (fp['sf'] + fp['pf']) / 2
fp['pf_c'] = (fp['pf'] + fp['c']) / 2
fp['c_pg'] = (fp['c'] + fp['pg']) / 2
print(fp)
# Out:
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# atl  4886  4129  4334  4460  4650  4507.5  4231.5  4397.0  4555.0  4768.0
# bos  4696  4009  4155  4782  4999  4352.5  4082.0  4468.5  4890.5  4847.5
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cha  4686  4149  4098  4629  5129  4417.5  4123.5  4363.5  4879.0  4907.5
# chi  4704  3907  4040  4606  4713  4305.5  3973.5  4323.0  4659.5  4708.5
# cle  4688  4325  4219  4408  4910  4506.5  4272.0  4313.5  4659.0  4799.0
# dal  4227  3959  3777  4506  4787  4093.0  3868.0  4141.5  4646.5  4507.0
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# det  4725  3766  3974  4519  4801  4245.5  3870.0  4246.5  4660.0  4763.0
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# ind  4581  3918  4290  4681  4937  4249.5  4104.0  4485.5  4809.0  4759.0
# lac  4349  3835  4154  4561  4842  4092.0  3994.5  4357.5  4701.5  4595.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# mem  4489  3855  3990  4183  4261  4172.0  3922.5  4086.5  4222.0  4375.0
# mia  4433  3681  3903  4429  4919  4057.0  3792.0  4166.0  4674.0  4676.0
# mil  4443  4002  4127  4543  4988  4222.5  4064.5  4335.0  4765.5  4715.5
# min  4608  4088  3964  4361  5130  4348.0  4026.0  4162.5  4745.5  4869.0
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5
# okc  4535  4094  4026  4553  4924  4314.5  4060.0  4289.5  4738.5  4729.5
# orl  4967  4138  4091  4713  5118  4552.5  4114.5  4402.0  4915.5  5042.5
# phi  4619  4095  4139  4590  5180  4357.0  4117.0  4364.5  4885.0  4899.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5
# sac  4601  4220  4062  4805  5007  4410.5  4141.0  4433.5  4906.0  4804.0
# sas  4543  3964  3572  4297  4596  4253.5  3768.0  3934.5  4446.5  4569.5
# tor  4470  3699  4116  4445  4880  4084.5  3907.5  4280.5  4662.5  4675.0
# uth  4495  3498  3519  4174  4538  3996.5  3508.5  3846.5  4356.0  4516.5
# was  4590  3897  4023  4735  5021  4243.5  3960.0  4379.0  4878.0  4805.5

# %%
# Finding the mean of the fantasy points by position
pg_avg = sum(fp['pg']) / len(fp['pg'])
sg_avg = sum(fp['sg']) / len(fp['sg'])
sf_avg = sum(fp['sf']) / len(fp['sf'])
pf_avg = sum(fp['pf']) / len(fp['pf'])
c_avg = sum(fp['c']) / len(fp['c'])
print(pg_avg)
print(sg_avg)
print(sf_avg)
print(pf_avg)
print(c_avg)
# Out:
# 4655
# 4021
# 4060
# 4610
# 4970

# %%
# Histogram of point guard fantasy points against each team as well as the mean, variance, and standard deviation
plt.hist(fp['pg'])
plt.axvline((fp['pg']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fp['pg']).mean() + (fp['pg']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fp['pg']).mean() - (fp['pg']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Point Guard')
plt.xlabel('points')
plt.show() 
pg_var = np.var(fp['pg'], ddof=1)
pg_std = np.std(fp['pg'], ddof=1)
print(pg_avg)
print(pg_var)
print(pg_std)
# Out:
# 4655
# 46987.4264368
# 216.765833186

# %%
# Histogram of shooting guard fantasy points against each team as well as the mean, variance, and standard deviation
plt.hist(fp['sg'])
plt.axvline(fp['sg'].mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(fp['sg'].mean() + fp['sg'].std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(fp['sg'].mean() - fp['sg'].std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Shooting Guard')
plt.xlabel('points')
plt.show()
sg_var = np.var(fp['sg'], ddof=1)
sg_std = np.std(fp['sg'], ddof=1)
print(sg_avg)
print(sg_var)
print(sg_std)
# Out:
# 4021
# 40503.0402299
# 201.253671345

# %%
# Histogram of small forward fantasy points against each team as well as the mean, variance, and standard deviation
plt.hist(fp['sf'])
plt.axvline(fp['sf'].mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(fp['sf'].mean() + fp['sf'].std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(fp['sf'].mean() - fp['sf'].std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Small Forward')
plt.xlabel('points')
plt.show()
sf_var = np.var(fp['sf'], ddof=1)
sf_std = np.std(fp['sf'], ddof=1)
print(sf_avg)
print(sf_var)
print(sf_std)
# Out:
# 4060
# 37025.8264368
# 192.420961532

# %%
# Histogram of power forward fantasy points against each team as well as the mean, variance, and standard deviation
plt.hist(fp['pf'])
plt.axvline(fp['pf'].mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(fp['pf'].mean() + fp['pf'].std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(fp['pf'].mean() - fp['pf'].std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Power Forward')
plt.xlabel('points')
plt.show()
pf_var = np.var(fp['pf'], ddof=1)
pf_std = np.std(fp['pf'], ddof=1)
print(pf_avg)
print(pf_var)
print(pf_std)
# Out:
# 4610
# 45867.9816092
# 214.168115295

# %%
# Histogram of center fantasy points against each team as well as the mean, variance, and standard deviation
plt.hist(fp['c'])
plt.axvline(fp['c'].mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(fp['c'].mean() + fp['c'].std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(fp['c'].mean() - fp['c'].std(), color='b', linestyle='dashed', linewidth=2) 
plt.title('Center')
plt.xlabel('points')
plt.show()
c_var = np.var(fp['c'], ddof=1)
c_std = np.std(fp['c'], ddof=1)
print(c_avg)
print(c_var)
print(c_std)
# Out:
# 4970
# 65427.8402299
# 255.788663216

# %%
# Finding the means of multiple positions to see if they correlate. Also looking for the overall mean
group_1 = (pg_avg + sg_avg) / 2
group_2 = (sg_avg + sf_avg) / 2
group_3 = (sf_avg + pf_avg) / 2
group_4 = (pf_avg + c_avg) / 2
group_5 = (pg_avg + c_avg) / 2
group_6 = (pg_avg + sg_avg + sf_avg) / 3
group_7 = (sg_avg + sf_avg + pf_avg) / 3
group_8 = (sf_avg + pf_avg + c_avg) / 3
group_9 = (pf_avg + c_avg + pg_avg) / 3
group_10 =(pg_avg + sf_avg + c_avg) / 3
group_11 = (pg_avg + sg_avg + sf_avg + pf_avg + c_avg) / 5
print(group_1)
print(group_2)
print(group_3)
print(group_4)
print(group_5)
print(group_6)
print(group_7)
print(group_8)
print(group_9)
print(group_10)
print(group_11)
# Out:
# 4338
# 4040
# 4335
# 4790
# 4812
# 4245
# 4230
# 4546
# 4745
# 4561
# 4463

# %%
# Histogram of the point guard and shooting guard fantasy scores to see if there is a visual correlation
plt.hist(fp['pg_sg'])
plt.axvline((fp['pg_sg']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fp['pg_sg']).mean() + (fp['pg_sg']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fp['pg_sg']).mean() - (fp['pg_sg']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
pg_sg_var = np.var(fp['pg_sg'], ddof=1)
pg_sg_std = np.std(fp['pg_sg'], ddof=1)
print(group_1)
print(pg_sg_var)
print(pg_sg_std)
# Out:
# 4338
# 35450.2517241
# 188.282372314

# %%
# Histogram of the shooting guard and small forward fantasy scores to see if there is a visual correlation
plt.hist(fp['sg_sf'])
plt.axvline((fp['sg_sf']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fp['sg_sf']).mean() - (fp['sg_sf']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.axvline((fp['sg_sf']).mean() + (fp['sg_sf']).std(), color='b', linestyle='dashed', linewidth=2)
plt.show()
sg_sf_var = np.var(fp['sg_sf'], ddof=1)
sg_sf_std = np.std(fp['sg_sf'], ddof=1)
print(group_2)
print(sg_sf_var)
print(sg_sf_std)
# Out:
# 4040
# 29311.9034483
# 171.207194499

# %%
# Histogram of the small forward and power forward fantasy scores to see if there is a visual correlation
plt.hist(fp['sf_pf'])
plt.axvline((fp['sf_pf']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fp['sf_pf']).mean() - (fp['sf_pf']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.axvline((fp['sf_pf']).mean() + (fp['sf_pf']).std(), color='b', linestyle='dashed', linewidth=2)
plt.show()
sf_pf_var = np.var(fp['sf_pf'], ddof=1)
sf_pf_std = np.std(fp['sf_pf'], ddof=1)
print(group_3)
print(sf_pf_var)
print(sf_pf_std)
# Out:
# 4335
# 33178.9772989
# 182.150973917

# %%
# Histogram of the power forward and center fantasy scores to see if there is a visual correlation
plt.hist(fp['pf_c'])
plt.axvline((fp['pf_c']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fp['pf_c']).mean() - (fp['pf_c']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.axvline((fp['pf_c']).mean() + (fp['pf_c']).std(), color='b', linestyle='dashed', linewidth=2)
plt.title('Power Forward and Center')
plt.xlabel('points')
plt.show()
pf_c_var = np.var(fp['pf_c'], ddof=1)
pf_c_std = np.std(fp['pf_c'], ddof=1)
print(group_4)
print(pf_c_var)
print(pf_c_std)
# Out:
# 4790
# 49948.2439655
# 223.491037774

# %%
# Histogram of the point guard and center fantasy scores to see if there is a visual correlation and, since there 
# should be no correlation based on the hypothesis. 
plt.hist(fp['c_pg'])
plt.axvline((fp['c_pg']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fp['c_pg']).mean() - (fp['c_pg']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.axvline((fp['c_pg']).mean() + (fp['c_pg']).std(), color='b', linestyle='dashed', linewidth=2)
plt.show()
c_pg_var = np.var(fp['c_pg'], ddof=1)
c_pg_std = np.std(fp['c_pg'], ddof=1)
print(group_5)
print(c_pg_var)
print(c_pg_std)
# Out:
# 4812
# 41709.0931034
# 204.228041913

# %%
# A side by side histogram of the point guard and shooting guard fantasy scores to see if there is a visual correlation
x = fp['pg']
y = fp['sg']
plt.hist(x, color='red', alpha=.5) 
plt.hist(y, color='blue', alpha=.5)
plt.show()

# %%
# A side by side histogram of the shooting guard and small forward fantasy scores to see if there is a visual correlation
x = fp['sg']
y = fp['sf']
plt.hist(x, color='red', alpha=.5) 
plt.hist(y, color='blue', alpha=.5)
plt.show()

# %%
# A side by side histogram of the small forward and power forward fantasy scores to see if there is a visual correlation
x = fp['sf']
y = fp['pf']
plt.hist(x, color='red', alpha=.5) 
plt.hist(y, color='blue', alpha=.5)
plt.show()

# %%
# A side by side histogram of the power forward and center fantasy scores to see if there is a visual correlation
x = fp['pf']
y = fp['c']
plt.title('Power Forward and Center')
plt.xlabel('points')
plt.hist(x, color='red', alpha=.5) 
plt.hist(y, color='blue', alpha=.5)
plt.show()

# %%
# A side by side histogram of the point guard and center fantasy scores to see if there is a visual correlation.
# Based on the hypothesis there should be little correlation.
x = fp['c']
y = fp['pg']
plt.hist(x, color='red', alpha=.5) 
plt.hist(y, color='blue', alpha=.5)
plt.show()

# %%
# A scatter plot of the point guard and shooting guard fantasy scores to see if there is a linear correlation
plt.scatter(x = fp['pg'], y = fp['sg'], color='purple')
plt.ylabel('sg')
plt.xlabel('pg')
plt.show()

# %%
# A scatter plot of the shooting guard and small forward fantasy scores to see if there is a linear correlation
plt.scatter(x = fp['sg'], y = fp['sf'], color='purple')
plt.ylabel('sf')
plt.xlabel('sg')
plt.show()

# %%
# A scatter plot of the small forward and power forward fantasy scores to see if there is a linear correlation
plt.scatter(x = fp['sf'], y = fp['pf'], color='purple')
plt.ylabel('pf')
plt.xlabel('sf')
plt.show()

# %%
# A scatter plot of the power forward and center fantasy scores to see if there is a linear correlation
plt.scatter(x = fp['pf'], y = fp['c'], color='purple')
plt.ylabel('c')
plt.xlabel('pf')
plt.show()

# %%
# A scatter plot of the center and point guard fantasy scores to see if there is a linear correlation
plt.scatter(x = fp['c'], y = fp['pg'], color='purple')
plt.ylabel('pg')
plt.xlabel('c')
plt.show()

# %%
# Creating a dataframe with the teams who allow more fantasy points to point guards then one STD above the mean. 
pg_tip = pg_avg + pg_std
pg_tip_tot = len(fp.ix[lambda df: fp['pg'] > pg_tip, :])
print(pg_tip_tot)
print(pg_tip)
fp.ix[lambda df: fp['pg'] > pg_tip, :]
# Out:
# 6
# 4871.76583319
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# atl  4886  4129  4334  4460  4650  4507.5  4231.5  4397.0  4555.0  4768.0
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# orl  4967  4138  4091  4713  5118  4552.5  4114.5  4402.0  4915.5  5042.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0

# %%
# Creating a dataframe with the teams who allow more fantasy points to shooting guards then one STD above the mean. 
sg_tip = sg_avg + sg_std
sg_tip_tot = len(fp.ix[lambda df: fp['sg'] > sg_tip, :])
print(sg_tip_tot)
print(sg_tip)
fp.ix[lambda df: fp['sg'] > sg_tip, :]
# Out:
# 4
# 4222.25367135
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cle  4688  4325  4219  4408  4910  4506.5  4272.0  4313.5  4659.0  4799.0
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0

# %%
# Creating a dataframe with the teams who allow more fantasy points to small forwards then one STD above the mean. 
sf_tip = sf_avg + sf_std
sf_tip_tot = len(fp.ix[lambda df: fp['sf'] > sf_tip, :])
print(sf_tip_tot)
print(sf_tip)
fp.ix[lambda df: fp['sf'] > sf_tip, :]
# Out:
# 4
# 4252.42096153
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# atl  4886  4129  4334  4460  4650  4507.5  4231.5  4397.0  4555.0  4768.0
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# ind  4581  3918  4290  4681  4937  4249.5  4104.0  4485.5  4809.0  4759.0
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to power forwards then one STD above the mean. 
pf_tip = pf_avg + pf_std
pf_tip_tot = len(fp.ix[lambda df: fp['pf'] > pf_tip, :])
print(pf_tip_tot)
print(pf_tip)
fp.ix[lambda df: fp['pf'] > pf_tip, :]
# Out:
# 4
# 4824.1681153
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to centers then one STD above the mean. 
c_tip = c_avg + c_std
c_tip_tot = len(fp.ix[lambda df: fp['c'] > c_tip, :])
print(c_tip_tot)
print(c_tip)
fp.ix[lambda df: fp['c'] > c_tip, :]
# Out:
# 3
# 0
# 5225.78866322
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to both power forwards and centers then one STD above the mean. 
pf_c_tip = group_4 + pf_c_std
pf_c_tip_tot = len(fp.ix[lambda df: fp['pf_c'] > pf_c_tip, :])
print(pf_c_tip_tot)
print(pf_c_tip)
fp.ix[lambda df: fp['pf_c'] > pf_c_tip, :]
# Out:
# 4
# 5013.49103777
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to point guards then the mean. 
pg_above_mid = len(fp.ix[lambda df: fp['pg'] > pg_avg, :])
print(pg_above_mid)
fp.ix[lambda df: fp['pg'] > pg_avg, :]
# Out:
# 13
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# atl  4886  4129  4334  4460  4650  4507.5  4231.5  4397.0  4555.0  4768.0
# bos  4696  4009  4155  4782  4999  4352.5  4082.0  4468.5  4890.5  4847.5
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cha  4686  4149  4098  4629  5129  4417.5  4123.5  4363.5  4879.0  4907.5
# chi  4704  3907  4040  4606  4713  4305.5  3973.5  4323.0  4659.5  4708.5
# cle  4688  4325  4219  4408  4910  4506.5  4272.0  4313.5  4659.0  4799.0
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# det  4725  3766  3974  4519  4801  4245.5  3870.0  4246.5  4660.0  4763.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0
# orl  4967  4138  4091  4713  5118  4552.5  4114.5  4402.0  4915.5  5042.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0

# %%
# Creating a dataframe with the teams who allow more fantasy points to shooting guards then the mean. 
sg_above_mid = len(fp.ix[lambda df: fp['sg'] > sg_avg, :])
print(sg_above_mid)
fp.ix[lambda df: fp['sg'] > sg_avg, :]
# Out:
# 15
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# atl  4886  4129  4334  4460  4650  4507.5  4231.5  4397.0  4555.0  4768.0
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cha  4686  4149  4098  4629  5129  4417.5  4123.5  4363.5  4879.0  4907.5
# cle  4688  4325  4219  4408  4910  4506.5  4272.0  4313.5  4659.0  4799.0
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# min  4608  4088  3964  4361  5130  4348.0  4026.0  4162.5  4745.5  4869.0
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5
# okc  4535  4094  4026  4553  4924  4314.5  4060.0  4289.5  4738.5  4729.5
# orl  4967  4138  4091  4713  5118  4552.5  4114.5  4402.0  4915.5  5042.5
# phi  4619  4095  4139  4590  5180  4357.0  4117.0  4364.5  4885.0  4899.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0
# sac  4601  4220  4062  4805  5007  4410.5  4141.0  4433.5  4906.0  4804.0

# %%
# Creating a dataframe with the teams who allow more fantasy points to small forwards then the mean. 
sf_above_mid = len(fp.ix[lambda df: fp['sf'] > sf_avg, :])
print(sf_above_mid)
fp.ix[lambda df: fp['sf'] > sf_avg, :]
# Out:
# 16
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# atl  4886  4129  4334  4460  4650  4507.5  4231.5  4397.0  4555.0  4768.0
# bos  4696  4009  4155  4782  4999  4352.5  4082.0  4468.5  4890.5  4847.5
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cha  4686  4149  4098  4629  5129  4417.5  4123.5  4363.5  4879.0  4907.5
# cle  4688  4325  4219  4408  4910  4506.5  4272.0  4313.5  4659.0  4799.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# ind  4581  3918  4290  4681  4937  4249.5  4104.0  4485.5  4809.0  4759.0
# lac  4349  3835  4154  4561  4842  4092.0  3994.5  4357.5  4701.5  4595.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# mil  4443  4002  4127  4543  4988  4222.5  4064.5  4335.0  4765.5  4715.5
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5
# orl  4967  4138  4091  4713  5118  4552.5  4114.5  4402.0  4915.5  5042.5
# phi  4619  4095  4139  4590  5180  4357.0  4117.0  4364.5  4885.0  4899.5
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5
# sac  4601  4220  4062  4805  5007  4410.5  4141.0  4433.5  4906.0  4804.0
# tor  4470  3699  4116  4445  4880  4084.5  3907.5  4280.5  4662.5  4675.0

# %%
# Creating a dataframe with the teams who allow more fantasy points to power forwards then the mean. 
pf_above_mid = len(fp.ix[lambda df: fp['pf'] > pf_avg, :])
print(pf_above_mid)
fp.ix[lambda df: fp['pf'] > pf_avg, :]
# Out:
# 15
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# bos  4696  4009  4155  4782  4999  4352.5  4082.0  4468.5  4890.5  4847.5
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cha  4686  4149  4098  4629  5129  4417.5  4123.5  4363.5  4879.0  4907.5
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# ind  4581  3918  4290  4681  4937  4249.5  4104.0  4485.5  4809.0  4759.0
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5
# orl  4967  4138  4091  4713  5118  4552.5  4114.5  4402.0  4915.5  5042.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5
# sac  4601  4220  4062  4805  5007  4410.5  4141.0  4433.5  4906.0  4804.0
# was  4590  3897  4023  4735  5021  4243.5  3960.0  4379.0  4878.0  4805.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to centers then the mean. 
c_above_mid = len(fp.ix[lambda df: fp['c'] > c_avg, :])
print(c_above_mid)
fp.ix[lambda df: fp['c'] > c_avg, :]
# Out:
# 17
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# bos  4696  4009  4155  4782  4999  4352.5  4082.0  4468.5  4890.5  4847.5
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cha  4686  4149  4098  4629  5129  4417.5  4123.5  4363.5  4879.0  4907.5
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# mil  4443  4002  4127  4543  4988  4222.5  4064.5  4335.0  4765.5  4715.5
# min  4608  4088  3964  4361  5130  4348.0  4026.0  4162.5  4745.5  4869.0
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5
# orl  4967  4138  4091  4713  5118  4552.5  4114.5  4402.0  4915.5  5042.5
# phi  4619  4095  4139  4590  5180  4357.0  4117.0  4364.5  4885.0  4899.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5
# sac  4601  4220  4062  4805  5007  4410.5  4141.0  4433.5  4906.0  4804.0
# was  4590  3897  4023  4735  5021  4243.5  3960.0  4379.0  4878.0  4805.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to both power forwards and centers then the mean. 
# Also, creating a percentage of teams who allow more fantasy points to power forwards and centers then the mean.
pf_c_above_mid = len(fp.ix[lambda df: fp['pf_c'] > group_4, :])
print(pf_c_above_mid)
print(pf_c_above_mid / 30)
fp.ix[lambda df: fp['pf_c'] > group_4, :]
# Out:
# 16
# 0
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# bos  4696  4009  4155  4782  4999  4352.5  4082.0  4468.5  4890.5  4847.5
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cha  4686  4149  4098  4629  5129  4417.5  4123.5  4363.5  4879.0  4907.5
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# ind  4581  3918  4290  4681  4937  4249.5  4104.0  4485.5  4809.0  4759.0
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5
# orl  4967  4138  4091  4713  5118  4552.5  4114.5  4402.0  4915.5  5042.5
# phi  4619  4095  4139  4590  5180  4357.0  4117.0  4364.5  4885.0  4899.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5
# sac  4601  4220  4062  4805  5007  4410.5  4141.0  4433.5  4906.0  4804.0
# was  4590  3897  4023  4735  5021  4243.5  3960.0  4379.0  4878.0  4805.5

# %%
pg_floor = [(pg_avg - min(fp['pg'])), (max(fp['pg']) - pg_avg)]  
print(pg_floor)
sg_floor = [(sg_avg - min(fp['sg'])), (max(fp['sg']) - sg_avg)] 
print(sg_floor)
sf_floor = [(sf_avg - min(fp['sf'])), (max(fp['sf']) - sf_avg)]  
print(sf_floor)
pf_floor = [(pf_avg - min(fp['pf'])), (max(fp['pf']) - pf_avg)]
print(pf_floor)
c_floor = [(c_avg - min(fp['c'])), (max(fp['c']) - c_avg)]
print(c_floor)
# Out:
# [428, 488]
# [523, 336]
# [541, 356]
# [436, 451]
# [709, 514]

# %%
# Calculating the difference between the ceilings and floors of each position
def score_difference(pg_floor):
    x = pg_floor[1]
    y = pg_floor[0]
    diff = x + y
    return diff
pg_diff = score_difference(pg_floor)
print(pg_diff)
sg_diff = score_difference(sg_floor)
print(sg_diff)
sf_diff = score_difference(sf_floor)
print(sf_diff)
pf_diff = score_difference(pf_floor)
print(pf_diff)
c_diff = score_difference(c_floor)
print(c_diff)
# Out:
# 916
# 859
# 897
# 887
# 1223

# %%
# Building dataframe of fantasy points scored against for each team broken down by position and an average of similar
# positions
fpf = pd.DataFrame(pd.read_csv('fppgf.csv', nrows=30))
fpf.columns = ['pg', 'sg', 'sf', 'pf', 'c']
fpf.index = ['atl', 'bos', 'bkn', 'cha', 'chi', 'cle', 'dal', 'den', 'det', 'gsw', 'hou', 'ind', 'lac', 'lal', 'mem', 'mia', 'mil', 'min', 'nop', 'nyk', 'okc', 'orl', 'phi', 'pho', 'por', 'sac', 'sas', 'tor', 'uth', 'was']
fpf['pg_sg'] = (fpf['pg'] + fpf['sg']) / 2
fpf['sg_sf'] = (fpf['sg'] + fpf['sf']) / 2
fpf['sf_pf'] = (fpf['sf'] + fpf['pf']) / 2
fpf['pf_c'] = (fpf['pf'] + fpf['c']) / 2
fpf['c_pg'] = (fpf['c'] + fpf['pg']) / 2
print(fpf)
# Out:
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# atl  4514  3855  3791  4773  5652  4184.5  3823.0  4282.0  5212.5  5083.0
# bos  4969  4117  4020  3878  4873  4543.0  4068.5  3949.0  4375.5  4921.0
# bkn  4107  4041  4696  4776  5204  4074.0  4368.5  4736.0  4990.0  4655.5
# cha  4965  4503  3948  4169  4182  4734.0  4225.5  4058.5  4175.5  4573.5
# chi  4256  5198  3141  4380  4031  4727.0  4169.5  3760.5  4205.5  4143.5
# cle  5245  3118  5429  5144  3887  4181.5  4273.5  5286.5  4515.5  4566.0
# dal  4208  3828  3587  4712  4204  4018.0  3707.5  4149.5  4458.0  4206.0
# den  4042  4115  4417  4962  6313  4078.5  4266.0  4689.5  5637.5  5177.5
# det  4605  3601  3790  3934  6146  4103.0  3695.5  3862.0  5040.0  5375.5
# gsw  5534  4061  6426  5341  5415  4797.5  5243.5  5883.5  5378.0  5474.5
# hou  4224  5922  3655  4309  5505  5073.0  4788.5  3982.0  4907.0  4864.5
# ind  4647  3549  4477  4245  5402  4098.0  4013.0  4361.0  4823.5  5024.5
# lac  5252  3675  3160  4622  5402  4463.5  3417.5  3891.0  5012.0  5327.0
# lal  4740  4576  3701  5250  4321  4658.0  4138.5  4475.5  4785.5  4530.5
# mem  4651  3544  3229  4411  5394  4097.5  3386.5  3820.0  4902.5  5022.5
# mia  5210  3777  3168  4627  6062  4493.5  3472.5  3897.5  5344.5  5636.0
# mil  3061  4070  4841  4455  5330  3565.5  4455.5  4648.0  4892.5  4195.5
# min  4230  2345  4162  5605  4036  3287.5  3253.5  4883.5  4820.5  4133.0
# nop  4478  3905  2858  6021  5123  4191.5  3381.5  4439.5  5572.0  4800.5
# nyk  4389  3514  4392  5255  5074  3951.5  3953.0  4823.5  5164.5  4731.5
# okc  7000  3482  3023  3466  4734  5241.0  3252.5  3244.5  4100.0  5867.0
# orl  4264  3631  3743  4411  5088  3947.5  3687.0  4077.0  4749.5  4676.0
# phi  4330  3440  4213  4933  5761  3885.0  3826.5  4573.0  5347.0  5045.5
# pho  4986  4399  3655  4505  4686  4692.5  4027.0  4080.0  4595.5  4836.0
# por  5770  4081  3728  4175  6322  4925.5  3904.5  3951.5  5248.5  6046.0
# sac  4041  3382  4323  3677  5476  3711.5  3852.5  4000.0  4576.5  4758.5
# sas  3936  3759  5278  4701  5068  3847.5  4518.5  4989.5  4884.5  4502.0
# tor  4588  4989  3608  3640  4529  4788.5  4298.5  3624.0  4084.5  4558.5
# uth  3845  3801  4238  4247  4652  3823.0  4019.5  4242.5  4449.5  4248.5
# was  5755  4304  3879  4266  4346  5029.5  4091.5  4072.5  4306.0  5050.5

# %%
# Finding the mean of the fantasy points earned by position
pgf_avg = sum(fpf['pg']) / len(fpf['pg'])
sgf_avg = sum(fpf['sg']) / len(fpf['sg'])
sff_avg = sum(fpf['sf']) / len(fpf['sf'])
pff_avg = sum(fpf['pf']) / len(fpf['pf'])
cf_avg = sum(fpf['c']) / len(fpf['c'])
print(pgf_avg)
print(sgf_avg)
print(sff_avg)
print(pff_avg)
print(cf_avg)
# Out:
# 4661
# 3952
# 4019
# 4563
# 5073

# %%
# Histogram of point guard fantasy points earned on each team as well as the mean, variance, and standard deviation
plt.hist(fpf['pg'])
plt.axvline((fpf['pg']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fpf['pg']).mean() + (fpf['pg']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fpf['pg']).mean() - (fpf['pg']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
pgf_var = np.var(fpf['pg'], ddof=1)
pgf_std = np.std(fpf['pg'], ddof=1)
print(pgf_avg)
print(pgf_var)
print(pgf_std)
# Out:
# 4661
# 549226.937931
# 741.098467095

# %%
# Histogram of shooting guard fantasy points earned on each team as well as the mean, variance, and standard deviation
plt.hist(fpf['sg'])
plt.axvline((fpf['sg']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fpf['sg']).mean() + (fpf['sg']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fpf['sg']).mean() - (fpf['sg']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
sgf_var = np.var(fpf['sg'], ddof=1)
sgf_std = np.std(fpf['sg'], ddof=1)
print(sgf_avg)
print(sgf_var)
print(sgf_std)
# Out:
# 3952
# 436445.71954
# 660.640385944

# %%
# Histogram of small forward fantasy points earned on each team as well as the mean, variance, and standard deviation
plt.hist(fpf['sf'])
plt.axvline((fpf['sf']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fpf['sf']).mean() + (fpf['sf']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fpf['sf']).mean() - (fpf['sf']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
sff_var = np.var(fpf['sf'], ddof=1)
sff_std = np.std(fpf['sf'], ddof=1)
print(sff_avg)
print(sff_var)
print(sff_std)
# Out:
# 4019
# 600523.751724
# 774.934675779

# %%
# Histogram of power forward fantasy points earned on each team as well as the mean, variance, and standard deviation
plt.hist(fpf['pf'])
plt.axvline((fpf['pf']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fpf['pf']).mean() + (fpf['pf']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fpf['pf']).mean() - (fpf['pf']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
pff_var = np.var(fpf['pf'], ddof=1)
pff_std = np.std(fpf['pf'], ddof=1)
print(pff_avg)
print(pff_var)
print(pff_std)
# Out:
# 4563
# 344793.37931
# 587.191092669

# %%
# Histogram of center fantasy points earned on each team as well as the mean, variance, and standard deviation
plt.hist(fpf['c'])
plt.axvline((fpf['c']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fpf['c']).mean() + (fpf['c']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fpf['c']).mean() - (fpf['c']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
cf_var = np.var(fpf['c'], ddof=1)
cf_std = np.std(fpf['c'], ddof=1)
print(cf_avg)
print(cf_var)
print(cf_std)
# Out:
# 5073
# 479164.202299
# 692.216875191

# %%
# Finding the means of multiple positions to see if they correlate. Also looking for the overall mean
group_21 = (pgf_avg + sgf_avg) / 2
group_22 = (sgf_avg + sff_avg) / 2
group_23 = (sff_avg + pff_avg) / 2
group_24 = (pff_avg + cf_avg) / 2
group_25 = (pgf_avg + cf_avg) / 2
group_26 = (pgf_avg + sgf_avg + sff_avg + pff_avg + cf_avg) / 5
print(group_21)
print(group_22)
print(group_23)
print(group_24)
print(group_25)
print(group_26)
# Out:
# 4306
# 3985
# 4291
# 4818
# 4867
# 4453

# %%
# Histogram of the point guard and shooting guard fantasy scores for each team to see if there is a visual correlation
plt.hist(fpf['pg_sg'])
plt.axvline((fpf['pg_sg']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fpf['pg_sg']).mean() + (fpf['pg_sg']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fpf['pg_sg']).mean() - (fpf['pg_sg']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
pgf_sgf_var = np.var(fpf['pg_sg'], ddof=1)
pgf_sgf_std = np.std(fpf['pg_sg'], ddof=1)
print(group_21)
print(pgf_sgf_var)
print(pgf_sgf_std)
# Out:
# 4306
# 233373.564368
# 483.087532822

# %%
# Histogram of the shooting guard and small forward fantasy scores for each team to see if there is a visual correlation
plt.hist(fpf['sg_sf'])
plt.axvline((fpf['sg_sf']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fpf['sg_sf']).mean() + (fpf['sg_sf']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fpf['sg_sf']).mean() - (fpf['sg_sf']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
sgf_sff_var = np.var(fpf['sg_sf'], ddof=1)
sgf_sff_std = np.std(fpf['sg_sf'], ddof=1)
print(group_22)
print(sgf_sff_var)
print(sgf_sff_std)
# Out:
# 4306
# 206388.447126
# 454.299952814

# %%
# Histogram of the small forward and power forward fantasy scores for each team to see if there is a visual correlation
plt.hist(fpf['sf_pf'])
plt.axvline((fpf['sf_pf']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fpf['sf_pf']).mean() + (fpf['sf_pf']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fpf['sf_pf']).mean() - (fpf['sf_pf']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
sff_pff_var = np.var(fpf['sf_pf'], ddof=1)
sff_pff_std = np.std(fpf['sf_pf'], ddof=1)
print(group_23)
print(sff_pff_var)
print(sff_pff_std)
# Out:
# 4291
# 291156.782759
# 539.589457605

# %%
# Histogram of the power forward and center fantasy scores for each team to see if there is a visual correlation
plt.hist(fpf['pf_c'])
plt.axvline((fpf['pf_c']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fpf['pf_c']).mean() + (fpf['pf_c']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fpf['pf_c']).mean() - (fpf['pf_c']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
pff_cf_var = np.var(fpf['pf_c'], ddof=1)
pff_cf_std = np.std(fpf['pf_c'], ddof=1)
print(group_24)
print(pff_cf_var)
print(pff_cf_std)
# Out:
# 4818
# 189078.085057
# 434.83109946

# %%
# Histogram of the center and point guard fantasy scores for each team to see if there is a visual correlation
plt.hist(fpf['c_pg'])
plt.axvline((fpf['c_pg']).mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline((fpf['c_pg']).mean() + (fpf['c_pg']).std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline((fpf['c_pg']).mean() - (fpf['c_pg']).std(), color='b', linestyle='dashed', linewidth=2) 
plt.show()
cf_pgf_var = np.var(fpf['c_pg'], ddof=1)
cf_pgf_std = np.std(fpf['c_pg'], ddof=1)
print(group_25)
print(cf_pgf_var)
print(cf_pgf_std)
# Out:
# 4867
# 243062.488506
# 493.013679836

# %%
# A scatter plot of the point guard and shooting guard fantasy points earned to see if there is a linear correlation
plt.scatter(x = fpf['pg'], y = fpf['sg'], color='purple')
plt.ylabel('sg')
plt.xlabel('pg')
plt.show()

# %%
# A scatter plot of the shooting guard and small forward fantasy points earned to see if there is a linear correlation
plt.scatter(x = fpf['sg'], y = fpf['sf'], color='purple')
plt.ylabel('sf')
plt.xlabel('sg')
plt.show()

# %%
# A scatter plot of the point guard and shooting guard fantasy points earned to see if there is a linear correlation
plt.scatter(x = fpf['sf'], y = fpf['pf'], color='purple')
plt.ylabel('pf')
plt.xlabel('sf')
plt.show()

# %%
# A scatter plot of the power forward and center fantasy points earned to see if there is a linear correlation
plt.scatter(x = fpf['pf'], y = fpf['c'], color='purple')
plt.ylabel('c')
plt.xlabel('pf')
plt.show()

# %%
# A scatter plot of the center and point guard fantasy points earned to see if there is a linear correlation
plt.scatter(x = fpf['c'], y = fpf['pg'], color='purple')
plt.ylabel('pg')
plt.xlabel('c')
plt.show()

# %%
# Creating a dataframe with the teams who allow more fantasy points to point guards 
# then one STD above the mean. 
pgf_tip = pgf_avg + pgf_std
pgf_tip_tot = len(fp.ix[lambda df: fpf['pg'] > pgf_tip, :])
print(pgf_tip_tot)
print(pgf_tip)
fp.ix[lambda df: fpf['pg'] > pgf_tip, :]
# Out:
# 4
# 5402.0984671
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# okc  4535  4094  4026  4553  4924  4314.5  4060.0  4289.5  4738.5  4729.5
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5
# was  4590  3897  4023  4735  5021  4243.5  3960.0  4379.0  4878.0  4805.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to shooting guards 
# then one STD above the mean. 
sgf_tip = sgf_avg + sgf_std
sgf_tip_tot = len(fp.ix[lambda df: fpf['sg'] > sgf_tip, :])
print(sgf_tip_tot)
print(sgf_tip)
fp.ix[lambda df: fpf['sg'] > sgf_tip, :]
# Out:
# 3
# 4612.64038594
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# chi  4704  3907  4040  4606  4713  4305.5  3973.5  4323.0  4659.5  4708.5
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# tor  4470  3699  4116  4445  4880  4084.5  3907.5  4280.5  4662.5  4675.0

# %%
# Creating a dataframe with the teams who allow more fantasy points to small forwards 
# then one STD above the mean. 
sff_tip = sff_avg + sff_std
sff_tip_tot = len(fp.ix[lambda df: fpf['sf'] > pff_tip, :])
print(sff_tip_tot)
print(sff_tip)
fp.ix[lambda df: fpf['sf'] > sff_tip, :]
# Out:
# 5
# 4793.93467578
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# cle  4688  4325  4219  4408  4910  4506.5  4272.0  4313.5  4659.0  4799.0
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# mil  4443  4002  4127  4543  4988  4222.5  4064.5  4335.0  4765.5  4715.5
# sas  4543  3964  3572  4297  4596  4253.5  3768.0  3934.5  4446.5  4569.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to power forwards 
# then one STD above the mean. 
pff_tip = pff_avg + pff_std
pff_tip_tot = len(fp.ix[lambda df: fpf['pf'] > pff_tip, :])
print(pff_tip_tot)
print(pff_tip)
fp.ix[lambda df: fpf['pf'] > pff_tip, :]
# Out:
# 5
# 5150.19109267
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# min  4608  4088  3964  4361  5130  4348.0  4026.0  4162.5  4745.5  4869.0
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to centers
# then one STD above the mean. 
cf_tip = cf_avg + cf_std
cf_tip_tot = len(fp.ix[lambda df: fpf['c'] > cf_tip, :])
print(cf_tip_tot)
print(cf_tip)
fp.ix[lambda df: fpf['c'] > cf_tip, :]
# Out:
# 4
# 5765.21687519
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# det  4725  3766  3974  4519  4801  4245.5  3870.0  4246.5  4660.0  4763.0
# mia  4433  3681  3903  4429  4919  4057.0  3792.0  4166.0  4674.0  4676.0
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to shooting guards 
# then one STD above the mean. 
pff_cf_tip = group_24 + sgf_std
pff_cf_tip_tot = len(fp.ix[lambda df: fpf['pf_c'] > pff_cf_tip, :])
print(pff_cf_tip_tot)
print(pff_cf_tip)
fp.ix[lambda df: fpf['pf_c'] > pff_cf_tip, :]
# Out:
# 2
# 5478.64038594
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0

# %%
# Creating a dataframe with the teams who allow more fantasy points to point guards then the mean. 
pgf_above_mid = len(fp.ix[lambda df: fpf['pg'] > pgf_avg, :])
print(pgf_above_mid)
fp.ix[lambda df: fpf['pg'] > pgf_avg, :]
# Out:
# 11
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# bos  4696  4009  4155  4782  4999  4352.5  4082.0  4468.5  4890.5  4847.5
# cha  4686  4149  4098  4629  5129  4417.5  4123.5  4363.5  4879.0  4907.5
# cle  4688  4325  4219  4408  4910  4506.5  4272.0  4313.5  4659.0  4799.0
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# lac  4349  3835  4154  4561  4842  4092.0  3994.5  4357.5  4701.5  4595.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# mia  4433  3681  3903  4429  4919  4057.0  3792.0  4166.0  4674.0  4676.0
# okc  4535  4094  4026  4553  4924  4314.5  4060.0  4289.5  4738.5  4729.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5
# was  4590  3897  4023  4735  5021  4243.5  3960.0  4379.0  4878.0  4805.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to shooting guards then the mean. 
sgf_above_mid = len(fp.ix[lambda df: fpf['sg'] > sgf_avg, :])
print(sgf_above_mid)
fp.ix[lambda df: fpf['sg'] > sgf_avg, :]
# Out:
# 13
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# bos  4696  4009  4155  4782  4999  4352.5  4082.0  4468.5  4890.5  4847.5
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cha  4686  4149  4098  4629  5129  4417.5  4123.5  4363.5  4879.0  4907.5
# chi  4704  3907  4040  4606  4713  4305.5  3973.5  4323.0  4659.5  4708.5
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# mil  4443  4002  4127  4543  4988  4222.5  4064.5  4335.0  4765.5  4715.5
# pho  4938  4231  4059  4838  5180  4584.5  4145.0  4448.5  5009.0  5059.0
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5
# tor  4470  3699  4116  4445  4880  4084.5  3907.5  4280.5  4662.5  4675.0
# was  4590  3897  4023  4735  5021  4243.5  3960.0  4379.0  4878.0  4805.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to small forwards then the mean. 
sff_above_mid = len(fp.ix[lambda df: fpf['sf'] > sff_avg, :])
print(sff_above_mid)
fp.ix[lambda df: fpf['sf'] > sff_avg, :]
# Out:
# 13
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# bos  4696  4009  4155  4782  4999  4352.5  4082.0  4468.5  4890.5  4847.5
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cle  4688  4325  4219  4408  4910  4506.5  4272.0  4313.5  4659.0  4799.0
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# ind  4581  3918  4290  4681  4937  4249.5  4104.0  4485.5  4809.0  4759.0
# mil  4443  4002  4127  4543  4988  4222.5  4064.5  4335.0  4765.5  4715.5
# min  4608  4088  3964  4361  5130  4348.0  4026.0  4162.5  4745.5  4869.0
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5
# phi  4619  4095  4139  4590  5180  4357.0  4117.0  4364.5  4885.0  4899.5
# sac  4601  4220  4062  4805  5007  4410.5  4141.0  4433.5  4906.0  4804.0
# sas  4543  3964  3572  4297  4596  4253.5  3768.0  3934.5  4446.5  4569.5
# uth  4495  3498  3519  4174  4538  3996.5  3508.5  3846.5  4356.0  4516.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to power forwards then the mean. 
pff_above_mid = len(fp.ix[lambda df: fpf['pf'] > pff_avg, :])
print(pff_above_mid)
fp.ix[lambda df: fpf['pf'] > pff_avg, :]
# Out:
# 14
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# atl  4886  4129  4334  4460  4650  4507.5  4231.5  4397.0  4555.0  4768.0
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# cle  4688  4325  4219  4408  4910  4506.5  4272.0  4313.5  4659.0  4799.0
# dal  4227  3959  3777  4506  4787  4093.0  3868.0  4141.5  4646.5  4507.0
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# lac  4349  3835  4154  4561  4842  4092.0  3994.5  4357.5  4701.5  4595.5
# lal  5031  4082  4347  5061  5484  4556.5  4214.5  4704.0  5272.5  5257.5
# mia  4433  3681  3903  4429  4919  4057.0  3792.0  4166.0  4674.0  4676.0
# min  4608  4088  3964  4361  5130  4348.0  4026.0  4162.5  4745.5  4869.0
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5
# phi  4619  4095  4139  4590  5180  4357.0  4117.0  4364.5  4885.0  4899.5
# sas  4543  3964  3572  4297  4596  4253.5  3768.0  3934.5  4446.5  4569.5

# %%
# Creating a dataframe with the teams who allow more fantasy points to shooting guards then the mean. 
cf_above_mid = len(fp.ix[lambda df: fpf['c'] > cf_avg, :])
print(cf_above_mid)
fp.ix[lambda df: fpf['c'] > cf_avg, :]
# Out:
# 17
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# atl  4886  4129  4334  4460  4650  4507.5  4231.5  4397.0  4555.0  4768.0
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# det  4725  3766  3974  4519  4801  4245.5  3870.0  4246.5  4660.0  4763.0
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# ind  4581  3918  4290  4681  4937  4249.5  4104.0  4485.5  4809.0  4759.0
# lac  4349  3835  4154  4561  4842  4092.0  3994.5  4357.5  4701.5  4595.5
# mem  4489  3855  3990  4183  4261  4172.0  3922.5  4086.5  4222.0  4375.0
# mia  4433  3681  3903  4429  4919  4057.0  3792.0  4166.0  4674.0  4676.0
# mil  4443  4002  4127  4543  4988  4222.5  4064.5  4335.0  4765.5  4715.5
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5
# orl  4967  4138  4091  4713  5118  4552.5  4114.5  4402.0  4915.5  5042.5
# phi  4619  4095  4139  4590  5180  4357.0  4117.0  4364.5  4885.0  4899.5
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5
# sac  4601  4220  4062  4805  5007  4410.5  4141.0  4433.5  4906.0  4804.0

# %%
# Creating a dataframe with the teams who gain more fantasy points to both power forwards and centers then the mean. 
pff_cf_above_mid = len(fp.ix[lambda df: fpf['pf_c'] > group_24, :])
print(pff_cf_above_mid)
fp.ix[lambda df: fpf['pf_c'] > group_24, :]
# Out:
# 17
#        pg    sg    sf    pf     c   pg_sg   sg_sf   sf_pf    pf_c    c_pg
# atl  4886  4129  4334  4460  4650  4507.5  4231.5  4397.0  4555.0  4768.0
# bkn  5143  4357  4416  4960  5317  4750.0  4386.5  4688.0  5138.5  5230.0
# den  4982  4326  3998  4671  5021  4654.0  4162.0  4334.5  4846.0  5001.5
# det  4725  3766  3974  4519  4801  4245.5  3870.0  4246.5  4660.0  4763.0
# gsw  4484  3967  4060  4671  4994  4225.5  4013.5  4365.5  4832.5  4739.0
# hou  4827  4152  4173  4787  5364  4489.5  4162.5  4480.0  5075.5  5095.5
# ind  4581  3918  4290  4681  4937  4249.5  4104.0  4485.5  4809.0  4759.0
# lac  4349  3835  4154  4561  4842  4092.0  3994.5  4357.5  4701.5  4595.5
# mem  4489  3855  3990  4183  4261  4172.0  3922.5  4086.5  4222.0  4375.0
# mia  4433  3681  3903  4429  4919  4057.0  3792.0  4166.0  4674.0  4676.0
# mil  4443  4002  4127  4543  4988  4222.5  4064.5  4335.0  4765.5  4715.5
# min  4608  4088  3964  4361  5130  4348.0  4026.0  4162.5  4745.5  4869.0
# nop  4860  4193  4045  4711  5098  4526.5  4119.0  4378.0  4904.5  4979.0
# nyk  4526  4133  4078  4677  5201  4329.5  4105.5  4377.5  4939.0  4863.5
# phi  4619  4095  4139  4590  5180  4357.0  4117.0  4364.5  4885.0  4899.5
# por  4531  3966  4070  4948  5128  4248.5  4018.0  4509.0  5038.0  4829.5
# sas  4543  3964  3572  4297  4596  4253.5  3768.0  3934.5  4446.5  4569.5

# %%
pf_list = ['bos', 'bkn', 'cha', 'den', 'gsw', 'hou', 'ind', 'lal', 'nop', 'nyk', 'orl', 'pho', 'por', 'sac', 'was']
c_list = ['bos', 'bkn', 'cha', 'den','gsw', 'hou', 'lal', 'mil', 'min', 'nop', 'nyk', 'orl', 'phi', 'pho', 'por', 'sac', 'was']
t_list = []
for player in pf_list:
    t_list.append(player)
for player in c_list:
    t_list.append(player)

both_positions = {}
for player in t_list:
    if player not in both_positions:
        both_positions[player] = 1
    elif player in both_positions:
        both_positions[player] += 1

both_num = list(both_positions.values()) 
in_both = []
for num in both_num:
    if num == 2:
        in_both.append(num)
print(len(pf_list))
print(len(c_list))
print(len(in_both))
# Out:
# 15
# 17
# 14

# %%
print(max(fp['pf']))
print(max(fp['c']))
# Out:
# 5061
# 5484
