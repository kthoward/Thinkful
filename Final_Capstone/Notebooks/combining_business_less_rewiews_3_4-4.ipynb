# %%
import pandas as pd
from datetime import datetime
import numpy as np
import json
import glob
import keras
from datetime import timedelta
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Flatten
import spacy
from keras.layers import Dropout
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
import json
import seaborn as sns
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
yelp_reviews = pd.read_csv('yelp_reviews_to_merge_3_4.csv')
# Out:
# /Users/kylehoward/Desktop/Thinkful/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
yelp_business = pd.read_csv('real_business_to_merge_with_reviews_3_4')

# %%
yelp_reviews = yelp_reviews.sort_values('date', ascending = False)

# %%
yelp_reviews.iloc[1037796:, :]
# Out:
#                                                 Unnamed: 0  \
# 4386965                                            4386963
# 4616759                                            4616757
# 2142041                                            2142040
# 213933                                              213933
# 4513232                                            4513230
# 1427201                                            1427201
# 1691241                                            1691241
# 1878847                                            1878846
# 2806943                                            2806942
# 2794682                                            2794681
# 3995302                                            3995300
# 3511326                                            3511324
# 1737898                                            1737898
# 213901                                              213901
# 4616745                                            4616743
# ...

# %%
yelp_reviews_2 = yelp_reviews.iloc[1037796:, :]

# %%
yelp_reviews_2 = yelp_reviews_2.iloc[:, 1:]

# %%
yelp_reviews_2 = yelp_reviews_2.iloc[:-2, :]

# %%
yelp_reviews_2.tail()
# Out:
#                     business_id        date  \
# 3502787  GCRvrxMSC1nzShyM4Y-guQ  2004-10-19
# 4665150  u8C8pRvaHXg3PgDrsUHJHQ  2004-10-19
# 5205791  PD2MAlYYi9HCqPH7IBKwTg  2004-10-12
# 759789   9X-43jnj6-6ZBuBdFm7BLA  2004-09-15
# 2368500  uz7UbvVUwsg68Rok6kbqRg  2004-07-22
#
#                                                       text
# 3502787  New club in the Hard Rock, and currently the h...
# 4665150      Good stuff. Pricey by normal pizza standards.
# 5205791  Hole in the wall burrito joint with the BEST b...
# 759789   Viel Auswahl täuscht über die wahre Tatsache h...
# 2368500  Sehr gutes Restaurant, leckeres essen und nett...

# %%
yelp_business_less_reviews_full = pd.merge(yelp_business, yelp_reviews_2, right_on='business_id', left_on='business_id', how='inner')

# %%
yelp_business_less_reviews_full.head()
# Out:
#    postal_code             business_id        date  \
# 0        95966  bujMV3UPks8INgBnjV9gcw  2017-01-31
# 1        95966  bujMV3UPks8INgBnjV9gcw  2017-01-03
# 2        95966  bujMV3UPks8INgBnjV9gcw  2016-12-28
# 3        95966  bujMV3UPks8INgBnjV9gcw  2016-10-04
# 4        95966  bujMV3UPks8INgBnjV9gcw  2016-09-02
#
#                                                 text
# 0  Where to begin? Well, this was the WORST insta...
# 1  Oh I wish that I researched Delta Mechanical o...
# 2  This is a fraudulent company. I bought my wate...
# 3  Delta Mechanical is the sub-contractor through...
# 4  PLEASE HELP!!!\n\nHow do I get home Depot to r...

# %%
yelp_business_less_reviews_full.tail()
# Out:
#          postal_code             business_id        date  \
# 3539486         5440  tJRDll5yqpZwehenzE2cSg  2012-07-26
# 3539487         2224  2mroQ_qD_5kLTv88zADnXg  2016-10-12
# 3539488         2224  2mroQ_qD_5kLTv88zADnXg  2016-02-01
# 3539489         2224  2mroQ_qD_5kLTv88zADnXg  2015-09-21
# 3539490         2224  2mroQ_qD_5kLTv88zADnXg  2015-06-05
#
#                                                       text
# 3539486  Unbelievable cute nicest owners ever. I got in...
# 3539487  The service here is TERRIBLE!!  They told me t...
# 3539488  Every time I go through the drive through they...
# 3539489  Normally I consider eating at a McDonald's a d...
# 3539490  One of the better Mickey D's in the area. Fast...

# %%
yelp_business_less_reviews_full.to_csv('yelp_reviews_business_pre_vec_3_4_2016.csv')
