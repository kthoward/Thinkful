# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.cluster import SpectralClustering
from sklearn.cluster import AffinityPropagation
from sklearn import metrics
# %matplotlib inline
import os
os.getcwd()
os.chdir('/Users/kylehoward/desktop/thinkful/thinkful-2') 
os.getcwd()
# Out:
# '/Users/kylehoward/Desktop/Thinkful/Thinkful-2'

# %%
data = ("bmar_results.csv")
df = pd.read_csv(data)
df['30k'].astype(int, errors='ignore')
df['40k'].astype(int, errors='ignore')
df = df.drop('country', axis=1)
df = df.drop('ctz', axis=1)
df = df.drop('city', axis=1)
df = df.drop('state', axis=1)
df = df.drop('bib', axis=1)
df = df.sort_values('5k', ascending=True)
df.describe()
# Out:
#            division           age      official     genderdiv       overall  \
# count  31984.000000  31984.000000  31984.000000  31984.000000  31984.000000
# mean    1932.563032     42.407079    242.997314   8051.044741  15939.587825
# std     1715.228694     11.316496     52.300431   4754.005626   9232.978224
# min        1.000000     18.000000     80.600000      1.000000      1.000000
# 25%      610.000000     33.000000    205.527500   3972.000000   7943.750000
# 50%     1425.000000     42.000000    232.370000   7970.000000  15939.500000
# 75%     2611.000000     50.000000    273.235000  11968.000000  23935.250000
# max     6979.000000     81.000000    538.880000  17575.000000  31931.000000
#
#                pace
# count  31984.000000
# mean       9.275658
# std        1.992486
# min        3.080000
# 25%        7.850000
# 50%        8.870000
# 75%       10.430000
# max       20.570000

# %%
f_k = []
fk = df['5k']
for i in fk:
    if i == '-':
        i = 0 
        f_k.append(i)
    else:
        f_k.append(1)
df['5k_comp'] = f_k

t_k = []
tk = df['10k']
for i in tk:
    if i == '-':
        i = 0 
        t_k.append(i)
    else:
        t_k.append(1)
df['10k_comp'] = t_k

h_k = []
hk = df['half']
for i in hk:
    if i == '-':
        i = 0 
        h_k.append(i)
    else:
        h_k.append(1)
df['half_comp'] = h_k

tw_k = []
twk = df['20k']
for i in twk:
    if i == '-':
        i = 0 
        tw_k.append(i)
    else:
        tw_k.append(1)
df['20k_comp'] = tw_k

twf_k = []
twfk = df['25k']
for i in twfk:
    if i == '-':
        i = 0 
        twf_k.append(i)
    else:
        twf_k.append(1)
df['25k_comp'] = twf_k

th_k = []
thk = df['30k']
for i in thk:
    if i == '-':
        i = 0 
        th_k.append(i)
    else:
        th_k.append(1)
df['30k_comp'] = th_k

thf_k = []
thfk = df['35k']
for i in thfk:
    if i == '-':
        i = 0 
        thf_k.append(i)
    else:
        thf_k.append(1)
df['35k_comp'] = thf_k

for_k = []
fork = df['40k']
for i in fork:
    if i == '-':
        i = 0 
        for_k.append(i)
    else:
        for_k.append(1)
df['40k_comp'] = for_k

# %%
df.head(50)
# Out:
#          10k                          name  division     25k gender  age  \
# 30818  55.42             Joyce, Patrick H.      4521  145.93      M   39
# 836    38.28          Moosbrugger, Michael      2701  100.75      M   32
# 24071   59.8             Ligenza, Brett R.      2693  158.65      M   45
# 19686      -              Chapman, Nancy L        16       -      F   50
# 8419       -              Pater, Stephen W      2150  117.15      M   42
# 28688      -                Olsen, Jenifer       827       -      F   41
# 26875  59.18          McLaughlin, Laura K.      1086  154.48      F   53
# 27144      -               Maples, Alex S.      2993  117.77      F   28
# 29082      -                  Olsen, Ron H      1812       -      M   47
# 17316  49.33      Didonato-Sroczenski, Gia      3020  127.45      F   36
# 27507  65.67               Slater, Lisa P.      5681  173.33      F   35
# 30819      -                Lapman, Helene        75       -      F   63
# ...

# %%
x = 1000
forty = []
for i in fork:
    if i == '-':
        i = x
        forty.append(i)
    else:
        forty.append(i)
df['40k'] = forty
df['40k'] = df['40k'].astype(float, errors='ignore')

x = 1000
thirtyfive = []
for i in thfk:
    if i == '-':
        i = x
        thirtyfive.append(i)
    else:
        thirtyfive.append(i)
df['35k'] = thirtyfive
df['35k'] = df['35k'].astype(float, errors='ignore')

x = 1000
thirty = []
for i in thk:
    if i == '-':
        i = x
        thirty.append(i)
    else:
        thirty.append(i)
df['30k'] = thirty
df['30k'] = df['30k'].astype(float, errors='ignore')

x = 1000
twentyfive = []
for i in twfk:
    if i == '-':
        i = x
        twentyfive.append(i)
    else:
        twentyfive.append(i)
df['25k'] = twentyfive
df['25k'] = df['25k'].astype(float, errors='ignore')

x = 1000
twenty = []
for i in twk:
    if i == '-':
        i = x
        twenty.append(i)
    else:
        twenty.append(i)
df['20k'] = twenty
df['20k'] = df['20k'].astype(float, errors='ignore')

x = 1000
half = []
for i in hk:
    if i == '-':
        i = x
        half.append(i)
    else:
        half.append(i)
df['half'] = half
df['half'] = df['half'].astype(float, errors='ignore')

x = 1000
ten = []
for i in tk:
    if i == '-':
        i = x
        ten.append(i)
    else:
        ten.append(i)
df['10k'] = ten
df['10k'] = df['10k'].astype(float, errors='ignore')

x = 1000
five = []
for i in fk:
    if i == '-':
        i = x
        five.append(i)
    else:
        five.append(i)
df['5k'] = five
df['5k'] = df['5k'].astype(float, errors='ignore')

df.head(50)
# Out:
#            10k                          name  division      25k gender  age  \
# 30818    55.42             Joyce, Patrick H.      4521   145.93      M   39
# 836      38.28          Moosbrugger, Michael      2701   100.75      M   32
# 24071    59.80             Ligenza, Brett R.      2693   158.65      M   45
# 19686  1000.00              Chapman, Nancy L        16  1000.00      F   50
# 8419   1000.00              Pater, Stephen W      2150   117.15      M   42
# 28688  1000.00                Olsen, Jenifer       827  1000.00      F   41
# 26875    59.18          McLaughlin, Laura K.      1086   154.48      F   53
# 27144  1000.00               Maples, Alex S.      2993   117.77      F   28
# 29082  1000.00                  Olsen, Ron H      1812  1000.00      M   47
# 17316    49.33      Didonato-Sroczenski, Gia      3020   127.45      F   36
# 27507    65.67               Slater, Lisa P.      5681   173.33      F   35
# ...

# %%
X = df
#X = pd.get_dummies(X)
X = normalize(X)

# Here we set the bandwidth. This function automatically derives a bandwidth
# number based on an inspection of the distances among points in the data.
bandwidth = estimate_bandwidth(X, quantile=0.2, n_samples=500)

# Declare and fit the model.
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(X)

# Extract cluster assignments for each data point.
labels = ms.labels_

# Coordinates of the cluster centers.
cluster_centers = ms.cluster_centers_

# Count our clusters.
n_clusters_ = len(np.unique(labels))

print("Number of estimated clusters: {}".format(n_clusters_))

# %%
sc = SpectralClustering(n_clusters=10)
sc.fit(X)
#labels = sc.labels_
#cluster_centers = sc.cluster_centers_

# Count our clusters.
#n_clusters_ = len(np.unique(labels))
#print("Number of estimated clusters: {}".format(n_clusters_))

# %%
af = AffinityPropagation().fit(X)
cluster_centers_indices = af.cluster_centers_indices_
n_clusters_ = len(cluster_centers_indices)
labels = af.labels_
print('Estimated number of clusters: {}'.format(n_clusters_))

# %%
y_pred = KMeans(n_clusters=10).fit_predict(X)
